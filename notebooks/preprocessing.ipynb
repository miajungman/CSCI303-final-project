# %%
import pandas as pd

path = '../data/movie_films.csv'
df = pd.read_csv(path)
df
# Out:
#                                             Title Release date  \
# 0                               Super Mario Bros.   1993-05-28
# 1                                   Double Dragon   1994-11-04
# 2                                  Street Fighter   1994-12-23
# 3                                   Mortal Kombat   1995-08-18
# 4                     Mortal Kombat: Annihilation   1997-11-21
# 5                                  Wing Commander   1999-03-12
# 6                         Lara Croft: Tomb Raider   2001-06-15
# 7                                   Resident Evil   2002-03-15
# 8    Lara Croft: Tomb Raider – The Cradle of Life   2003-07-25
# 9                               House of the Dead   2003-10-10
# 10                      Resident Evil: Apocalypse   2004-09-10
# 11                              Alone in the Dark   2005-01-28
# 12                                           Doom   2005-10-21
# 13                                     BloodRayne   2006-01-06
# ...

# %% [markdown]
# ### identifying what needs to be processed
# * release date
# * Worldwide box office
# * distributor
# * original game publisher

# %%
# Drop columns 'Release date', 'Worldwide box office, 'Distributor' and 'Original game publisher'
df = df.drop(['Release date', 'Worldwide box office', 'Distributor', 'Original game publisher'], axis=1)

# Make the change permanent
df = df.copy()

df
# Out:
#                                             Title  Rotten Tomatoes  Metacritic
# 0                               Super Mario Bros.             24.0        35.0
# 1                                   Double Dragon             13.0         NaN
# 2                                  Street Fighter             13.0        34.0
# 3                                   Mortal Kombat             44.0        60.0
# 4                     Mortal Kombat: Annihilation              2.0        11.0
# 5                                  Wing Commander             10.0        21.0
# 6                         Lara Croft: Tomb Raider             20.0        33.0
# 7                                   Resident Evil             36.0        33.0
# 8    Lara Croft: Tomb Raider – The Cradle of Life             24.0        43.0
# 9                               House of the Dead              3.0        15.0
# 10                      Resident Evil: Apocalypse             19.0        35.0
# ...

# %% [markdown]
# * This dataframe includes only the information we want to continue with going forward.
